# %%
import pandas as pd

# %%
df_cat = pd.DataFrame({
    'category': ('Elektronik', 
    'Fashion', 
    'Buku', 
    'Rumah Tangga', 
    'Kesehatan & Kecantikan', 
    'Olahraga', 
    'Otomotif', 
    'Mainan & Hobi')
})

df_cat.head(8)
# Out:
#                  category
# 0              Elektronik
# 1                 Fashion
# 2                    Buku
# 3            Rumah Tangga
# 4  Kesehatan & Kecantikan
# 5                Olahraga
# 6                Otomotif
# 7           Mainan & Hobi

# %%
df_cat.to_csv('Category_Data.csv', index=False)
